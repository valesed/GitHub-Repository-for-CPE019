# %% [markdown]
# <a href="https://colab.research.google.com/github/valesed/GitHub-Repository-for-CPE019/blob/main/Tower_of_Hanoi_Hands_on_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hands-on Activity 2.1: The Tower of Hanoi Problem

# %%
def print_pegs(pegs):
    print(f"A: {pegs['A']}")
    print(f"B: {pegs['B']}")
    print(f"C: {pegs['C']}")
    print("_" * 25)

def tower(n, start, aux, end, pegs):
    if n == 1:
        disk = pegs[start].pop()
        pegs[end].append(disk)
        print(f"Move disk {disk} from {start} to {end}")
        print_pegs(pegs)
        return

    tower(n - 1, start, end, aux, pegs)
    disk = pegs[start].pop()
    pegs[end].append(disk)
    print(f"Move disk {disk} from {start} to {end}")
    print_pegs(pegs)
    tower(n - 1, aux, start, end, pegs)

pegs = {
    "A": [4, 3, 2, 1],
    "B": [],
    "C": []
}
print("Initial State:")
print_pegs(pegs)
tower(4, "A", "B", "C", pegs)
# Out:
# Initial State:
# A: [4, 3, 2, 1]
# B: []
# C: []
# _________________________
# Move disk 1 from A to B
# A: [4, 3, 2]
# B: [1]
# C: []
# _________________________
# Move disk 2 from A to C
# A: [4, 3]
# B: [1]
# C: [2]
# _________________________
# Move disk 1 from B to C
# A: [4, 3]
# B: []
# C: [2, 1]
# _________________________
# Move disk 3 from A to B
# A: [4]
# B: [3]
# C: [2, 1]
# _________________________
# Move disk 1 from C to A
# A: [4, 1]
# B: [3]
# C: [2]
# _________________________
# Move disk 2 from C to B
# A: [4, 1]
# B: [3, 2]
# C: []
# _________________________
# Move disk 1 from A to B
# A: [4]
# B: [3, 2, 1]
# C: []
# _________________________
# Move disk 4 from A to C
# A: []
# B: [3, 2, 1]
# C: [4]
# _________________________
# Move disk 1 from B to C
# A: []
# B: [3, 2]
# C: [4, 1]
# _________________________
# Move disk 2 from B to A
# A: [2]
# B: [3]
# C: [4, 1]
# _________________________
# Move disk 1 from C to A
# A: [2, 1]
# B: [3]
# C: [4]
# ...

# %% [markdown]
# # **Observations**

# %% [markdown]
# In this Activity I have discovered that I have problems in visualizing this activity in terms of how the disks moves thus I used simulation tools (https://www.mathsisfun.com/games/towerofhanoi.html) to visualize it to execute this activity

# %% [markdown]
# # **Supplementary Activity**

# %% [markdown]
# 1.   Explain the programming paradigms/techniques (like recursion or dynamic programming) that you used to solve the given problem.
#
# *   In this Activity I used reecursive programming which is the most efficient in solving the hanoi tower because of the recursive nature of the problem which was n-1

# %% [markdown]
# 2.   Provide screenshots of the techniques and provide a quick analysis.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
